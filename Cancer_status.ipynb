# %% [markdown]
# #Loading Libaries

# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Importing all necessary libraries to facilitate prediction objective.

# %% [markdown]
# #Load Dataset

# %%
# Load Dataset
os.chdir('/content/drive/MyDrive/Colab/Datasets/')
df = pd.read_csv('survey_lung_cancer.csv')
df
# Out:
#     GENDER  AGE  SMOKING  ...  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 0        M   69        1  ...                      2           2          YES
# 1        M   74        2  ...                      2           2          YES
# 2        F   59        1  ...                      1           2           NO
# 3        M   63        2  ...                      2           2           NO
# 4        F   63        1  ...                      1           1           NO
# ..     ...  ...      ...  ...                    ...         ...          ...
# 304      F   56        1  ...                      2           1          YES
# 305      M   70        2  ...                      1           2          YES
# 306      M   58        2  ...                      1           2          YES
# 307      M   67        2  ...                      1           2          YES
# 308      M   62        1  ...                      2           1          YES
#
# [309 rows x 16 columns]

# %% [markdown]
# Dataset loaded from google drive

# %% [markdown]
# # Preprocessing Data

# %%
# Remove any missing values
df.dropna(inplace=True)

# Run one hot encoding for GENDER & LUNG_CANCER Columns
df_encoded = pd.get_dummies(df, columns=['GENDER', 'LUNG_CANCER'], drop_first=True)

# Split data to train and test
X = df_encoded.drop('LUNG_CANCER_YES', axis=1)
Y = df_encoded['LUNG_CANCER_YES']

# Split 80% Training, 20% Test.
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Check sizes
print(f'Training set: {X_train.shape}')
print(f'Test set: {X_test.shape}')
# Out:
# Training set: (247, 15)
# Test set: (62, 15)
